# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import RidgeCV, LassoCV
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler # 원-핫 인코딩, 표준 스케일링
from sklearn.compose import ColumnTransformer                   # 여러 컬럼에 다른 전처리 적용

# %%
car_df = pd.read_csv('./data/Dubizzle_used_car_sales.csv')
num_unique_including_nan = car_df['model'].unique().size
print(f"NaN을 포함한 'motors_trim'의 고유 값 개수 (unique().size): {num_unique_including_nan}")
# Out:
# NaN을 포함한 'motors_trim'의 고유 값 개수 (unique().size): 552

# %%
car_df
car_df =car_df.drop(['title','motors_trim','model','steering_side'], axis=1)

# %%
print("\n--- 'horsepower' 컬럼 전처리 직전 상태 ---")
print(car_df['horsepower'].head(15)) # 상위 15개 값 확인
print(car_df['horsepower'].info())   # 데이터 타입 및 Non-Null 개수 확인
print("전처리 직전 고유 값:", car_df['horsepower'].unique()) # 모든 고유 값 확인 (특히 NaN이 어떻게 표현되는지)
print("전처리 직전 NaN 값 개수:", car_df['horsepower'].isna().sum()) # NaN 개수 확인
# Out:
# --- 'horsepower' 컬럼 전처리 직전 상태 ---
# 0              Unknown
# 1         400 - 500 HP
# 2         400 - 500 HP
# 3         600 - 700 HP
# 4     Less than 150 HP
# 5         200 - 300 HP
# 6              Unknown
# 7              Unknown
# 8         200 - 300 HP
# 9         200 - 300 HP
# 10        500 - 600 HP
# 11        500 - 600 HP
# 12        300 - 400 HP
# 13    Less than 150 HP
# 14             Unknown
# Name: horsepower, dtype: object
# <class 'pandas.core.series.Series'>
# RangeIndex: 9970 entries, 0 to 9969
# Series name: horsepower
# Non-Null Count  Dtype
# --------------  -----
# 9970 non-null   object
# dtypes: object(1)
# memory usage: 78.0+ KB
# None
# 전처리 직전 고유 값: ['Unknown' '400 - 500 HP' '600 - 700 HP' 'Less than 150 HP' '200 - 300 HP'
#  '500 - 600 HP' '300 - 400 HP' '150 - 200 HP' '700 - 800 HP'
#  '800 - 900 HP' '900+ HP']
# 전처리 직전 NaN 값 개수: 0

# %%
y = car_df['price_in_aed'] # 'price_in_aed'를 y로 정의

# %%
import re

print("--- 전처리 전 car_df['horsepower'] 상태 ---")
print(car_df['horsepower'].head(15))
print(car_df['horsepower'].info())


# --- 1. horsepower 문자열을 숫자형 (NaN 포함)으로 파싱하는 함수 ---
def process_horsepower(hp_str):
    # Pandas의 NaN, Python의 None, NumPy의 np.nan 등 모든 형태의 결측치와 문자열이 아닌 값 처리
    if pd.isna(hp_str) or not isinstance(hp_str, str):
        return np.nan

    # 'unknown', 'n/a', 'na', 빈 문자열 등을 소문자로 변환 후 np.nan으로 처리
    # .strip().lower()를 먼저 적용하여 대소문자 및 앞뒤 공백 문제 해결
    if hp_str.strip().lower() in ['unknown', 'n/a', 'na', '']:
        return np.nan

    # ' HP', 'H P'와 같은 단위 제거 및 소문자 변환 후 앞뒤 공백 제거
    cleaned_str = re.sub(r'\s*hp\s*', '', hp_str.lower()).strip()

    if 'less than' in cleaned_str:
        match = re.search(r'\d+', cleaned_str) # 숫자 추출
        if match:
            return float(match.group(0)) * 0.5 # 예: Less than 150 -> 75
        else:
            return 75.0 # 숫자가 없으면 기본값
    elif re.search(r'\d+\s*[-–—]\s*\d+', cleaned_str): # 숫자 - 숫자 (다양한 대시 문자 포함)
        parts = re.split(r'[-–—]', cleaned_str)
        try:
            lower = float(parts[0].strip())
            upper = float(parts[1].strip())
            return (lower + upper) / 2
        except (ValueError, IndexError):
            return np.nan # 파싱 오류 시 NaN
    elif '+' in cleaned_str: # '900+' 같은 경우
        match = re.search(r'\d+', cleaned_str) # 숫자 추출
        if match:
            return float(match.group(0)) + 50.0 
        else:
            return np.nan
    else: 
        try:
            return float(cleaned_str)
        except ValueError:
            return np.nan # 최종 변환 실패 시 NaN

# 'horsepower' 컬럼에 함수 적용
if 'horsepower' in car_df.columns:
    print("\n알림: 'horsepower' 컬럼 전처리 시작 (문자열 -> 숫자 변환).")
    car_df['horsepower'] = car_df['horsepower'].apply(process_horsepower)
    print("알림: 'horsepower' 컬럼 문자열 -> 숫자 변환 완료.")

# horsepower 전처리 (문자열 -> 숫자 변환) 후 상태 확인
# 이 단계에서는 'Unknown'이 np.nan으로 변환되어 보일 것입니다.
print("\n--- horsepower 전처리 (문자열 -> 숫자 변환) 후 car_df['horsepower'] 상태 (NaN 포함) ---")
print(car_df['horsepower'].head(15))
print(car_df['horsepower'].info())
print("NaN 값 개수 (process_horsepower 적용 후):", car_df['horsepower'].isna().sum())


# --- 2. 'horsepower' 컬럼의 결측치(NaN)를 중앙값으로 채우기 ---
if 'horsepower' in car_df.columns:
    print("\n알림: 'horsepower' 컬럼의 결측치(NaN)를 중앙값으로 채웁니다.")
    # 이 단계에서 'Unknown'에서 변환된 NaN 값들이 중앙값으로 채워집니다.
    imputer = SimpleImputer(strategy='median')
    # imputer는 2D 배열을 기대하므로 car_df[['horsepower']]와 같이 DataFrame 형태로 전달합니다.
    car_df['horsepower'] = imputer.fit_transform(car_df[['horsepower']])
    print("알림: 'horsepower' 컬럼 결측치 처리 완료.")

# horsepower 전처리 (결측치 처리까지) 완료 후 최종 상태 확인
# 이 단계에서는 'Unknown'이었던 값들이 이제 중앙값으로 채워져 있을 것입니다.
print("\n--- horsepower 전처리 (결측치 처리 포함) 완료 후 car_df['horsepower'] 최종 상태 ---")
print(car_df['horsepower'].head(15))
print(car_df['horsepower'].info())
print("NaN 값 개수 (최종 확인):", car_df['horsepower'].isna().sum())

print("\n--- horsepower 컬럼에 대한 모든 전처리가 완료되었습니다. ---")
# Out:
# --- 전처리 전 car_df['horsepower'] 상태 ---
# 0              Unknown
# 1         400 - 500 HP
# 2         400 - 500 HP
# 3         600 - 700 HP
# 4     Less than 150 HP
# 5         200 - 300 HP
# 6              Unknown
# 7              Unknown
# 8         200 - 300 HP
# 9         200 - 300 HP
# 10        500 - 600 HP
# 11        500 - 600 HP
# 12        300 - 400 HP
# 13    Less than 150 HP
# 14             Unknown
# Name: horsepower, dtype: object
# <class 'pandas.core.series.Series'>
# RangeIndex: 9970 entries, 0 to 9969
# Series name: horsepower
# Non-Null Count  Dtype
# --------------  -----
# 9970 non-null   object
# dtypes: object(1)
# memory usage: 78.0+ KB
# None
#
# 알림: 'horsepower' 컬럼 전처리 시작 (문자열 -> 숫자 변환).
# 알림: 'horsepower' 컬럼 문자열 -> 숫자 변환 완료.
#
# --- horsepower 전처리 (문자열 -> 숫자 변환) 후 car_df['horsepower'] 상태 (NaN 포함) ---
# 0       NaN
# 1     450.0
# 2     450.0
# 3     650.0
# 4      75.0
# 5     250.0
# 6       NaN
# 7       NaN
# 8     250.0
# 9     250.0
# 10    550.0
# 11    550.0
# 12    350.0
# 13     75.0
# 14      NaN
# Name: horsepower, dtype: float64
# <class 'pandas.core.series.Series'>
# RangeIndex: 9970 entries, 0 to 9969
# Series name: horsepower
# Non-Null Count  Dtype
# --------------  -----
# 9156 non-null   float64
# dtypes: float64(1)
# memory usage: 78.0 KB
# None
# NaN 값 개수 (process_horsepower 적용 후): 814
#
# 알림: 'horsepower' 컬럼의 결측치(NaN)를 중앙값으로 채웁니다.
# 알림: 'horsepower' 컬럼 결측치 처리 완료.
#
# --- horsepower 전처리 (결측치 처리 포함) 완료 후 car_df['horsepower'] 최종 상태 ---
# 0     350.0
# 1     450.0
# 2     450.0
# 3     650.0
# 4      75.0
# 5     250.0
# 6     350.0
# 7     350.0
# 8     250.0
# 9     250.0
# 10    550.0
# 11    550.0
# 12    350.0
# 13     75.0
# 14    350.0
# Name: horsepower, dtype: float64
# <class 'pandas.core.series.Series'>
# RangeIndex: 9970 entries, 0 to 9969
# Series name: horsepower
# Non-Null Count  Dtype
# --------------  -----
# 9970 non-null   float64
# dtypes: float64(1)
# memory usage: 78.0 KB
# None
# NaN 값 개수 (최종 확인): 0
#
# --- horsepower 컬럼에 대한 모든 전처리가 완료되었습니다. ---

# %%
""" import re
# 이 함수는 문자열 형태의 마력 값을 파싱하여 숫자형으로 반환합니다.
# 'Unknown', 'Less than X HP', 'A - B HP', 'X+ HP', 순수 숫자 등 다양한 케이스를 처리합니다.
def process_horsepower(hp_str):
    # NaN이거나 문자열이 아니면 바로 NaN 반환 (Pandas의 NaN, None, np.nan 등 포함)
    if pd.isna(hp_str) or not isinstance(hp_str, str):
        return np.nan

    # 추가적인 결측치 문자열 처리: 'N/A', 빈 문자열 등을 np.nan으로 변환
    if hp_str.strip().lower() in ['unknown', 'n/a', 'na', '']:
        return np.nan

    # 모든 공백, 'HP', 'H P' 등을 제거하고 소문자로 변환하여 일관성 유지
    cleaned_str = re.sub(r'\s*hp\s*', '', hp_str.lower()).strip()

    if 'less than' in cleaned_str:
        match = re.search(r'\d+', cleaned_str) # 숫자 추출
        if match:
            return float(match.group(0)) * 0.5 # 예: Less than 150 -> 75
        else:
            return 75.0 # 숫자가 없으면 기본값
    elif re.search(r'\d+\s*[-–—]\s*\d+', cleaned_str): # 숫자 - 숫자 (다양한 대시 문자 포함)
        parts = re.split(r'[-–—]', cleaned_str)
        try:
            lower = float(parts[0].strip())
            upper = float(parts[1].strip())
            return (lower + upper) / 2
        except (ValueError, IndexError):
            return np.nan # 파싱 오류 시 NaN
    elif '+' in cleaned_str: # '900+' 같은 경우
        match = re.search(r'\d+', cleaned_str) # 숫자 추출
        if match:
            return float(match.group(0)) + 50.0 # 예: 900+ -> 950 (임의의 상한값)
        else:
            return np.nan
    else: # 순수한 숫자 형태의 문자열 (예: '100') 또는 예상치 못한 다른 형태
        try:
            return float(cleaned_str)
        except ValueError:
            return np.nan # 최종 변환 실패 시 NaN

# 'horsepower' 컬럼에 함수 적용
if 'horsepower' in car_df.columns:
    print("알림: 'horsepower' 컬럼 전처리 시작 (문자열 -> 숫자 변환).")
    car_df['horsepower'] = car_df['horsepower'].apply(process_horsepower)
    print("알림: 'horsepower' 컬럼 문자열 -> 숫자 변환 완료.")

# horsepower 전처리 (문자열 -> 숫자 변환) 후 상태 확인
print("\n--- horsepower 전처리 (문자열 -> 숫자 변환) 후 car_df['horsepower'] 상태 ---")
print(car_df['horsepower'].head(25)) # 좀 더 많은 행 확인
print(car_df['horsepower'].info())
print("NaN 값 개수 (process_horsepower 적용 후):", car_df['horsepower'].isna().sum())

# 2. 'horsepower' 컬럼의 결측치(NaN)를 중앙값으로 채우기
if 'horsepower' in car_df.columns:
    print("\n알림: 'horsepower' 컬럼의 결측치(NaN)를 중앙값으로 채웁니다.")
    # SimpleImputer를 사용하여 중앙값으로 채우기
    # imputer는 2D 배열을 기대하므로 reshape(-1, 1) 해줍니다.
    imputer = SimpleImputer(strategy='median')
    car_df['horsepower'] = imputer.fit_transform(car_df[['horsepower']])
    print("알림: 'horsepower' 컬럼 결측치 처리 완료.")

# horsepower 전처리 (결측치 처리까지) 완료 후 최종 상태 확인
print("\n--- horsepower 전처리 (결측치 처리 포함) 완료 후 car_df['horsepower'] 최종 상태 ---")
print(car_df['horsepower'].head(25)) # 최종 상태 확인
print(car_df['horsepower'].info())
print("NaN 값 개수 (최종 확인):", car_df['horsepower'].isna().sum())

print("\n--- horsepower 컬럼에 대한 모든 전처리가 완료되었습니다. ---") """
# Out:
# ' import re\n# 이 함수는 문자열 형태의 마력 값을 파싱하여 숫자형으로 반환합니다.\n# \'Unknown\', \'Less than X HP\', \'A - B HP\', \'X+ HP\', 순수 숫자 등 다양한 케이스를 처리합니다.\ndef process_horsepower(hp_str):\n    # NaN이거나 문자열이 아니면 바로 NaN 반환 (Pandas의 NaN, None, np.nan 등 포함)\n    if pd.isna(hp_str) or not isinstance(hp_str, str):\n        return np.nan\n\n    # 추가적인 결측치 문자열 처리: \'N/A\', 빈 문자열 등을 np.nan으로 변환\n    if hp_str.strip().lower() in [\'unknown\', \'n/a\', \'na\', \'\']:\n        return np.nan\n\n    # 모든 공백, \'HP\', \'H P\' 등을 제거하고 소문자로 변환하여 일관성 유지\n    cleaned_str = re.sub(r\'\\s*hp\\s*\', \'\', hp_str.lower()).strip()\n\n    if \'less than\' in cleaned_str:\n        match = re.search(r\'\\d+\', cleaned_str) # 숫자 추출\n        if match:\n            return float(match.group(0)) * 0.5 # 예: Less than 150 -> 75\n        else:\n            return 75.0 # 숫자가 없으면 기본값\n    elif re.search(r\'\\d+\\s*[-–—]\\s*\\d+\', cleaned_str): # 숫자 - 숫자 (다양한 대시 문자 포함)\n        parts = re.split(r\'[-–—]\', cleaned_str)\n        try:\n            lower = float(parts[0].strip())\n            upper = float(parts[1].strip())\n            return (lower + upper) / 2\n        except (ValueError, IndexError):\n            return np.nan # 파싱 오류 시 NaN\n    elif \'+\' in cleaned_str: # \'900+\' 같은 경우\n        match = re.search(r\'\\d+\', cleaned_str) # 숫자 추출\n        if match:\n            return float(match.group(0)) + 50.0 # 예: 900+ -> 950 (임의의 상한값)\n        else:\n            return np.nan\n    else: # 순수한 숫자 형태의 문자열 (예: \'100\') 또는 예상치 못한 다른 형태\n        try:\n            return float(cleaned_str)\n        except ValueError:\n            return np.nan # 최종 변환 실패 시 NaN\n\n# \'horsepower\' 컬럼에 함수 적용\nif \'horsepower\' in car_df.columns:\n    print("알림: \'horsepower\' 컬럼 전처리 시작 (문자열 -> 숫자 변환).")\n    car_df[\'horsepower\'] = car_df[\'horsepower\'].apply(process_horsepower)\n    print("알림: \'horsepower\' 컬럼 문자열 -> 숫자 변환 완료.")\n\n# horsepower 전처리 (문자열 -> 숫자 변환) 후 상태 확인\nprint("\n--- horsepower 전처리 (문자열 -> 숫자 변환) 후 car_df[\'horsepower\'] 상태 ---")\nprint(car_df[\'horsepower\'].head(25)) # 좀 더 많은 행 확인\nprint(car_df[\'horsepower\'].info())\nprint("NaN 값 개수 (process_horsepower 적용 후):", car_df[\'horsepower\'].isna().sum())\n\n# 2. \'horsepower\' 컬럼의 결측치(NaN)를 중앙값으로 채우기\nif \'horsepower\' in car_df.columns:\n    print("\n알림: \'horsepower\' 컬럼의 결측치(NaN)를 중앙값으로 채웁니다.")\n    # SimpleImputer를 사용하여 중앙값으로 채우기\n    # imputer는 2D 배열을 기대하므로 reshape(-1, 1) 해줍니다.\n    imputer = SimpleImputer(strategy=\'median\')\n    car_df[\'horsepower\'] = imputer.fit_transform(car_df[[\'horsepower\']])\n    print("알림: \'horsepower\' 컬럼 결측치 처리 완료.")\n\n# horsepower 전처리 (결측치 처리까지) 완료 후 최종 상태 확인\nprint("\n--- horsepower 전처리 (결측치 처리 포함) 완료 후 car_df[\'horsepower\'] 최종 상태 ---")\nprint(car_df[\'horsepower\'].head(25)) # 최종 상태 확인\nprint(car_df[\'horsepower\'].info())\nprint("NaN 값 개수 (최종 확인):", car_df[\'horsepower\'].isna().sum())\n\nprint("\n--- horsepower 컬럼에 대한 모든 전처리가 완료되었습니다. ---") '

# %%
X = car_df.drop('price_in_aed', axis=1) # 'price_in_aed'를 제외한 나머지 컬럼이 X가 됩니다.
X
# Out:
#       kilometers                 body_condition    mechanical_condition  \
# 0         167390         Perfect inside and out  Perfect inside and out
# 1          39000         Perfect inside and out  Perfect inside and out
# 2         200000         Perfect inside and out  Perfect inside and out
# 3          27000         Perfect inside and out  Perfect inside and out
# 4          69000         Perfect inside and out  Perfect inside and out
# ...          ...                            ...                     ...
# 9965      105777         Perfect inside and out  Perfect inside and out
# 9966       55640         Perfect inside and out  Perfect inside and out
# 9967         100         Perfect inside and out  Perfect inside and out
# 9968      140000  No accidents, very few faults  Perfect inside and out
# 9969       86000         Perfect inside and out  Perfect inside and out
#
#      seller_type             body_type no_of_cylinders  \
# 0         Dealer                   SUV               6
# 1         Dealer                   SUV               8
# 2         Dealer                 Sedan               6
# 3         Dealer  Hard Top Convertible               8
# 4          Owner                 Wagon               4
# ...          ...                   ...             ...
# 9965      Dealer                   SUV               8
# 9966       Owner                   SUV               8
# 9967      Dealer                   SUV               8
# 9968       Owner                 Sedan               4
# 9969      Dealer             Crossover               6
#
#            transmission_type        regional_specs  horsepower fuel_type  \
# 0     Automatic Transmission             GCC Specs       350.0  Gasoline
# 1     Automatic Transmission  North American Specs       450.0  Gasoline
# 2     Automatic Transmission             GCC Specs       450.0  Gasoline
# 3     Automatic Transmission             GCC Specs       650.0  Gasoline
# 4        Manual Transmission             GCC Specs        75.0  Gasoline
# ...                      ...                   ...         ...       ...
# 9965  Automatic Transmission             GCC Specs       550.0  Gasoline
# 9966  Automatic Transmission             GCC Specs       450.0  Gasoline
# 9967  Automatic Transmission                 Other       450.0  Gasoline
# 9968  Automatic Transmission             GCC Specs       175.0  Gasoline
# 9969     Manual Transmission             GCC Specs       250.0  Gasoline
#
#         year   color   emirate        company date_posted
# 0     2013.0  Silver     Dubai     mitsubishi   13/05/2022
# 1     2018.0   White   Sharjah      chevrolet   14/01/2022
# 2     2014.0    Blue   Sharjah  mercedes-benz   05/05/2022
# 3     2018.0     Red     Dubai        ferrari   30/04/2022
# 4     2020.0   White     Dubai        renault   13/05/2022
# ...      ...     ...       ...            ...          ...
# 9965  2015.0   White     Dubai     land-rover   18/11/2021
# 9966  2014.0   White     Dubai       cadillac   11/05/2022
# 9967     NaN   Black     Dubai     land-rover   14/12/2021
# 9968  2013.0   White     Dubai      chevrolet   06/03/2022
# 9969  2013.0  Orange     Dubai           jeep   04/12/2021
#
# [9970 rows x 15 columns]

# %%
from datetime import datetime

if 'date_posted ' in X.columns:
    X['date_posted_dt'] = pd.to_datetime(X['date_posted '], format='%d/%m/%Y', errors='coerce')
    print("\n알림: 'date_posted ' 컬럼이 datetime 객체로 변환되었습니다 ('date_posted_dt' 생성).")
else:
    print("\n경고: 'date_posted ' 컬럼이 X 데이터프레임에 없습니다.")

# 변환 후 상태 확인
print("\n--- 'date_posted_dt' 컬럼 정보 ---")
print(X['date_posted_dt'].info())
print(X['date_posted_dt'].head())


# --- 2. datetime 객체에서 유용한 숫자형 특성 파생 ---

# 예를 들어, X['date_posted_dt'].max()를 사용할 수도 있습니다.
reference_date = datetime(2023, 12, 31) # 예시: 2023년 12월 31일을 기준 날짜로 설정

if 'date_posted_dt' in X.columns:
    # 2.1 게시일로부터 경과 일수 (Days since posted)
    # NaT 값은 계산 시 NaN이 됩니다.
    X['days_since_posted'] = (reference_date - X['date_posted_dt']).dt.days
    print("알림: 'days_since_posted' 컬럼이 생성되었습니다.")

    # 2.2 게시 월 (Month of posting)
    X['post_month'] = X['date_posted_dt'].dt.month
    print("알림: 'post_month' 컬럼이 생성되었습니다.")

    # 2.3 게시 요일 (Day of week, 월=0, 일=6)
    X['post_day_of_week'] = X['date_posted_dt'].dt.dayofweek
    print("알림: 'post_day_of_week' 컬럼이 생성되었습니다.")

    # 'year' 컬럼이 차량 제조 연도라고 가정합니다.
    if 'year' in X.columns:
        X['age_at_post'] = X['date_posted_dt'].dt.year - X['year']
        # 만약 date_posted_dt.dt.year가 NaT로 인해 NaN이면 age_at_post도 NaN이 됩니다.
        X['age_at_post'] = X['age_at_post'].apply(lambda x: max(0, x) if pd.notna(x) else np.nan) # 나이가 음수가 되지 않도록 0으로 처리
        print("알림: 'age_at_post' 컬럼이 생성되었습니다.")
    else:
        print("경고: 'year' 컬럼이 없어 'age_at_post'를 생성할 수 없습니다.")

    # 2.5 게시 연도 (Post year) - 필요시
    X['post_year'] = X['date_posted_dt'].dt.year
    print("알림: 'post_year' 컬럼이 생성되었습니다.")


    # --- 3. 원본 'date_posted ' 및 중간 'date_posted_dt' 컬럼 삭제 ---
    X = X.drop(columns=['date_posted ', 'date_posted_dt'], errors='ignore')
    print("\n알림: 원본 'date_posted ' 및 중간 'date_posted_dt' 컬럼이 삭제되었습니다.")
else:
    print("\n경고: 'date_posted_dt' 컬럼이 없어 날짜 특성을 파생할 수 없습니다.")


# --- 4. 파생된 특성들이 추가된 X 데이터프레임 최종 확인 ---
print("\n--- 날짜 특성 공학 후 X 데이터프레임의 상위 5행 ---")
print(X.head())
print("\n--- 날짜 특성 공학 후 X 데이터프레임 정보 ---")
print(X.info())
# Out:
# 알림: 'date_posted ' 컬럼이 datetime 객체로 변환되었습니다 ('date_posted_dt' 생성).
#
# --- 'date_posted_dt' 컬럼 정보 ---
# <class 'pandas.core.series.Series'>
# RangeIndex: 9970 entries, 0 to 9969
# Series name: date_posted_dt
# Non-Null Count  Dtype
# --------------  -----
# 9970 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 78.0 KB
# None
# 0   2022-05-13
# 1   2022-01-14
# 2   2022-05-05
# 3   2022-04-30
# 4   2022-05-13
# Name: date_posted_dt, dtype: datetime64[ns]
# 알림: 'days_since_posted' 컬럼이 생성되었습니다.
# 알림: 'post_month' 컬럼이 생성되었습니다.
# 알림: 'post_day_of_week' 컬럼이 생성되었습니다.
# 알림: 'age_at_post' 컬럼이 생성되었습니다.
# 알림: 'post_year' 컬럼이 생성되었습니다.
#
# 알림: 원본 'date_posted ' 및 중간 'date_posted_dt' 컬럼이 삭제되었습니다.
#
# --- 날짜 특성 공학 후 X 데이터프레임의 상위 5행 ---
#    kilometers          body_condition    mechanical_condition seller_type  \
# 0      167390  Perfect inside and out  Perfect inside and out      Dealer
# 1       39000  Perfect inside and out  Perfect inside and out      Dealer
# 2      200000  Perfect inside and out  Perfect inside and out      Dealer
# 3       27000  Perfect inside and out  Perfect inside and out      Dealer
# 4       69000  Perfect inside and out  Perfect inside and out       Owner
#
#               body_type no_of_cylinders       transmission_type  \
# 0                   SUV               6  Automatic Transmission
# 1                   SUV               8  Automatic Transmission
# 2                 Sedan               6  Automatic Transmission
# 3  Hard Top Convertible               8  Automatic Transmission
# 4                 Wagon               4     Manual Transmission
#
#          regional_specs  horsepower fuel_type    year   color   emirate  \
# 0             GCC Specs       350.0  Gasoline  2013.0  Silver     Dubai
# 1  North American Specs       450.0  Gasoline  2018.0   White   Sharjah
# 2             GCC Specs       450.0  Gasoline  2014.0    Blue   Sharjah
# 3             GCC Specs       650.0  Gasoline  2018.0     Red     Dubai
# 4             GCC Specs        75.0  Gasoline  2020.0   White     Dubai
#
#          company  days_since_posted  post_month  post_day_of_week  \
# 0     mitsubishi                597           5                 4
# 1      chevrolet                716           1                 4
# 2  mercedes-benz                605           5                 3
# 3        ferrari                610           4                 5
# 4        renault                597           5                 4
#
#    age_at_post  post_year
# 0          9.0       2022
# 1          4.0       2022
# 2          8.0       2022
# 3          4.0       2022
# 4          2.0       2022
#
# --- 날짜 특성 공학 후 X 데이터프레임 정보 ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9970 entries, 0 to 9969
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   kilometers            9970 non-null   int64
#  1   body_condition        9970 non-null   object
#  2   mechanical_condition  9970 non-null   object
#  3   seller_type           9970 non-null   object
#  4   body_type             9970 non-null   object
#  5   no_of_cylinders       9889 non-null   object
#  6   transmission_type     9970 non-null   object
#  7   regional_specs        9970 non-null   object
#  8   horsepower            9970 non-null   float64
#  9   fuel_type             9970 non-null   object
#  10  year                  9000 non-null   float64
#  11  color                 9970 non-null   object
#  12  emirate               9970 non-null   object
#  13  company               9970 non-null   object
#  14  days_since_posted     9970 non-null   int64
#  15  post_month            9970 non-null   int32
#  16  post_day_of_week      9970 non-null   int32
#  17  age_at_post           9000 non-null   float64
#  18  post_year             9970 non-null   int32
# dtypes: float64(3), int32(3), int64(2), object(11)
# memory usage: 1.3+ MB
# None

# %%
print("--- 전처리 전 X 데이터프레임의 'no_of_cylinders' 정보 ---")
print(X['no_of_cylinders'].info())
print(X['no_of_cylinders'].head(10)) # 더 많은 샘플 확인


# --- 1. 'no_of_cylinders' 컬럼의 비정상 문자열을 NaN으로 변환 ---
if 'no_of_cylinders' in X.columns:
    print("\n알림: 'no_of_cylinders' 컬럼의 비정상 문자열을 NaN으로 변환합니다.")
    # Step 1.1: 컬럼을 문자열 타입으로 명시적으로 변환하여 .str accessor가 항상 작동하도록 합니다.
    # 이 과정에서 np.nan은 문자열 'nan'으로 변환됩니다.
    X['no_of_cylinders'] = X['no_of_cylinders'].astype(str)

    # Step 1.2: 대소문자 문제를 해결하기 위해 replace() 전에 .str.lower()를 적용합니다.
    X['no_of_cylinders'] = X['no_of_cylinders'].str.lower().replace(
        ['unknown', 'null', 'nome', 'none', '', 'nan'], 
        np.nan, # 대체될 값
        regex=False # 정규표현식 사용 안 함
    )
    print("알림: 비정상 문자열 NaN 변환 완료.")

    # 2. 'no_of_cylinders' 컬럼을 숫자형으로 강제 변환
    # 이제 문자열이 NaN으로 변환되었으므로, pd.to_numeric을 안전하게 적용합니다.
    try:
        X['no_of_cylinders'] = pd.to_numeric(X['no_of_cylinders'], errors='coerce')
        print("알림: 'no_of_cylinders' 컬럼이 숫자형으로 변환되었습니다.")
    except Exception as e:
        print(f"경고: 'no_of_cylinders' 컬럼을 숫자형으로 변환하는 데 실패했습니다: {e}")

    # 3. 'no_of_cylinders' 컬럼의 결측치(NaN)를 중앙값으로 채우기
    # SimpleImputer를 사용하여 중앙값으로 채웁니다.
    print("\n알림: 'no_of_cylinders' 컬럼의 결측치(NaN)를 중앙값으로 채웁니다.")
    imputer = SimpleImputer(strategy='median')
    X['no_of_cylinders'] = imputer.fit_transform(X[['no_of_cylinders']])
    print("알림: 'no_of_cylinders' 컬럼 결측치 처리 완료.")

else:
    print("\n알림: 'no_of_cylinders' 컬럼이 X 데이터프레임에 없습니다. 전처리할 필요가 없습니다.")


# --- 4. 변환 후 'no_of_cylinders' 컬럼 최종 상태 확인 ---
print("\n--- 전처리 완료 후 X 데이터프레임의 'no_of_cylinders' 정보 ---")
print(X['no_of_cylinders'].info())
print(X['no_of_cylinders'].head(10)) # 최종 상태 확인
print(f"\n최종 'no_of_cylinders' 컬럼의 NaN 개수: {X['no_of_cylinders'].isna().sum()}")

print("\n--- 'no_of_cylinders' 컬럼에 대한 모든 전처리가 완료되었습니다. ---")
# Out:
# --- 전처리 전 X 데이터프레임의 'no_of_cylinders' 정보 ---
# <class 'pandas.core.series.Series'>
# RangeIndex: 9970 entries, 0 to 9969
# Series name: no_of_cylinders
# Non-Null Count  Dtype
# --------------  -----
# 9889 non-null   object
# dtypes: object(1)
# memory usage: 78.0+ KB
# None
# 0    6
# 1    8
# 2    6
# 3    8
# 4    4
# 5    6
# 6    8
# 7    4
# 8    6
# 9    6
# Name: no_of_cylinders, dtype: object
#
# 알림: 'no_of_cylinders' 컬럼의 비정상 문자열을 NaN으로 변환합니다.
# 알림: 비정상 문자열 NaN 변환 완료.
# 알림: 'no_of_cylinders' 컬럼이 숫자형으로 변환되었습니다.
#
# 알림: 'no_of_cylinders' 컬럼의 결측치(NaN)를 중앙값으로 채웁니다.
# 알림: 'no_of_cylinders' 컬럼 결측치 처리 완료.
#
# --- 전처리 완료 후 X 데이터프레임의 'no_of_cylinders' 정보 ---
# <class 'pandas.core.series.Series'>
# RangeIndex: 9970 entries, 0 to 9969
# Series name: no_of_cylinders
# Non-Null Count  Dtype
# --------------  -----
# 9970 non-null   float64
# dtypes: float64(1)
# memory usage: 78.0 KB
# None
# 0    6.0
# 1    8.0
# 2    6.0
# 3    8.0
# 4    4.0
# 5    6.0
# 6    8.0
# 7    4.0
# 8    6.0
# 9    6.0
# Name: no_of_cylinders, dtype: float64
#
# 최종 'no_of_cylinders' 컬럼의 NaN 개수: 0
#
# --- 'no_of_cylinders' 컬럼에 대한 모든 전처리가 완료되었습니다. ---

# %%
X
# Out:
#       kilometers                 body_condition    mechanical_condition  \
# 0         167390         Perfect inside and out  Perfect inside and out
# 1          39000         Perfect inside and out  Perfect inside and out
# 2         200000         Perfect inside and out  Perfect inside and out
# 3          27000         Perfect inside and out  Perfect inside and out
# 4          69000         Perfect inside and out  Perfect inside and out
# ...          ...                            ...                     ...
# 9965      105777         Perfect inside and out  Perfect inside and out
# 9966       55640         Perfect inside and out  Perfect inside and out
# 9967         100         Perfect inside and out  Perfect inside and out
# 9968      140000  No accidents, very few faults  Perfect inside and out
# 9969       86000         Perfect inside and out  Perfect inside and out
#
#      seller_type             body_type  no_of_cylinders  \
# 0         Dealer                   SUV              6.0
# 1         Dealer                   SUV              8.0
# 2         Dealer                 Sedan              6.0
# 3         Dealer  Hard Top Convertible              8.0
# 4          Owner                 Wagon              4.0
# ...          ...                   ...              ...
# 9965      Dealer                   SUV              8.0
# 9966       Owner                   SUV              8.0
# 9967      Dealer                   SUV              8.0
# 9968       Owner                 Sedan              4.0
# 9969      Dealer             Crossover              6.0
#
#            transmission_type        regional_specs  horsepower fuel_type  \
# 0     Automatic Transmission             GCC Specs       350.0  Gasoline
# 1     Automatic Transmission  North American Specs       450.0  Gasoline
# 2     Automatic Transmission             GCC Specs       450.0  Gasoline
# 3     Automatic Transmission             GCC Specs       650.0  Gasoline
# 4        Manual Transmission             GCC Specs        75.0  Gasoline
# ...                      ...                   ...         ...       ...
# 9965  Automatic Transmission             GCC Specs       550.0  Gasoline
# 9966  Automatic Transmission             GCC Specs       450.0  Gasoline
# 9967  Automatic Transmission                 Other       450.0  Gasoline
# 9968  Automatic Transmission             GCC Specs       175.0  Gasoline
# 9969     Manual Transmission             GCC Specs       250.0  Gasoline
#
#         year   color   emirate        company  days_since_posted  post_month  \
# 0     2013.0  Silver     Dubai     mitsubishi                597           5
# 1     2018.0   White   Sharjah      chevrolet                716           1
# 2     2014.0    Blue   Sharjah  mercedes-benz                605           5
# 3     2018.0     Red     Dubai        ferrari                610           4
# 4     2020.0   White     Dubai        renault                597           5
# ...      ...     ...       ...            ...                ...         ...
# 9965  2015.0   White     Dubai     land-rover                773          11
# 9966  2014.0   White     Dubai       cadillac                599           5
# 9967     NaN   Black     Dubai     land-rover                747          12
# 9968  2013.0   White     Dubai      chevrolet                665           3
# 9969  2013.0  Orange     Dubai           jeep                757          12
#
#       post_day_of_week  age_at_post  post_year
# 0                    4          9.0       2022
# 1                    4          4.0       2022
# 2                    3          8.0       2022
# 3                    5          4.0       2022
# 4                    4          2.0       2022
# ...                ...          ...        ...
# 9965                 3          6.0       2021
# 9966                 2          8.0       2022
# 9967                 1          NaN       2021
# 9968                 6          9.0       2022
# 9969                 5          8.0       2021
#
# [9970 rows x 19 columns]

# %%
# --- 1. 원-핫 인코딩할 컬럼 정의 ---
# 'body_condition'과 'mechanical_conditions'만 원-핫 인코딩합니다.
columns_to_one_hot_encode = [
    'body_condition',
    'mechanical_condition',
    'seller_type',
    'body_type',
    'transmission_type',
    'regional_specs',
    'fuel_type',
    'emirate',
    'color',
    'company'
]

# 실제로 X에 존재하는 컬럼만 선택 (안전 장치)
columns_to_one_hot_encode = [col for col in columns_to_one_hot_encode if col in X.columns]

print(f"\n원-핫 인코딩 대상 컬럼: {columns_to_one_hot_encode}")


X_processed = pd.get_dummies(X, columns=columns_to_one_hot_encode, drop_first=False)
# Out:
# 원-핫 인코딩 대상 컬럼: ['body_condition', 'mechanical_condition', 'seller_type', 'body_type', 'transmission_type', 'regional_specs', 'fuel_type', 'emirate', 'color', 'company']

# %%
X_processed
# Out:
#       kilometers  no_of_cylinders  horsepower    year  days_since_posted  \
# 0         167390              6.0       350.0  2013.0                597
# 1          39000              8.0       450.0  2018.0                716
# 2         200000              6.0       450.0  2014.0                605
# 3          27000              8.0       650.0  2018.0                610
# 4          69000              4.0        75.0  2020.0                597
# ...          ...              ...         ...     ...                ...
# 9965      105777              8.0       550.0  2015.0                773
# 9966       55640              8.0       450.0  2014.0                599
# 9967         100              8.0       450.0     NaN                747
# 9968      140000              4.0       175.0  2013.0                665
# 9969       86000              6.0       250.0  2013.0                757
#
#       post_month  post_day_of_week  age_at_post  post_year  \
# 0              5                 4          9.0       2022
# 1              1                 4          4.0       2022
# 2              5                 3          8.0       2022
# 3              4                 5          4.0       2022
# 4              5                 4          2.0       2022
# ...          ...               ...          ...        ...
# 9965          11                 3          6.0       2021
# 9966           5                 2          8.0       2022
# 9967          12                 1          NaN       2021
# 9968           3                 6          9.0       2022
# 9969          12                 5          8.0       2021
#
#       body_condition_A bit of wear & tear, all repaired  ...  company_skoda  \
# 0                                                 False  ...          False
# 1                                                 False  ...          False
# 2                                                 False  ...          False
# 3                                                 False  ...          False
# 4                                                 False  ...          False
# ...                                                 ...  ...            ...
# 9965                                              False  ...          False
# 9966                                              False  ...          False
# 9967                                              False  ...          False
# 9968                                              False  ...          False
# 9969                                              False  ...          False
#
#       company_smart  company_ssang-yong  company_subaru  company_suzuki  \
# 0             False               False           False           False
# 1             False               False           False           False
# 2             False               False           False           False
# 3             False               False           False           False
# 4             False               False           False           False
# ...             ...                 ...             ...             ...
# 9965          False               False           False           False
# 9966          False               False           False           False
# 9967          False               False           False           False
# 9968          False               False           False           False
# 9969          False               False           False           False
#
#       company_tesla  company_toyota  company_volkswagen  company_volvo  \
# 0             False           False               False          False
# 1             False           False               False          False
# 2             False           False               False          False
# 3             False           False               False          False
# 4             False           False               False          False
# ...             ...             ...                 ...            ...
# 9965          False           False               False          False
# 9966          False           False               False          False
# 9967          False           False               False          False
# 9968          False           False               False          False
# 9969          False           False               False          False
#
#       company_westfield-sportscars
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
# ...                            ...
# 9965                         False
# 9966                         False
# 9967                         False
# 9968                         False
# 9969                         False
#
# [9970 rows x 151 columns]

# %%
print(car_df.columns.tolist())
car_df
# Out:
# ['price_in_aed', 'kilometers', 'body_condition', 'mechanical_condition', 'seller_type', 'body_type', 'no_of_cylinders', 'transmission_type', 'regional_specs', 'horsepower', 'fuel_type', 'year', 'color', 'emirate', 'company', 'date_posted ']
#       price_in_aed  kilometers                 body_condition  \
# 0            26000      167390         Perfect inside and out
# 1           110000       39000         Perfect inside and out
# 2            78000      200000         Perfect inside and out
# 3           899000       27000         Perfect inside and out
# 4            33000       69000         Perfect inside and out
# ...            ...         ...                            ...
# 9965        215000      105777         Perfect inside and out
# 9966         90000       55640         Perfect inside and out
# 9967        679000         100         Perfect inside and out
# 9968         18900      140000  No accidents, very few faults
# 9969         77700       86000         Perfect inside and out
#
#         mechanical_condition seller_type             body_type  \
# 0     Perfect inside and out      Dealer                   SUV
# 1     Perfect inside and out      Dealer                   SUV
# 2     Perfect inside and out      Dealer                 Sedan
# 3     Perfect inside and out      Dealer  Hard Top Convertible
# 4     Perfect inside and out       Owner                 Wagon
# ...                      ...         ...                   ...
# 9965  Perfect inside and out      Dealer                   SUV
# 9966  Perfect inside and out       Owner                   SUV
# 9967  Perfect inside and out      Dealer                   SUV
# 9968  Perfect inside and out       Owner                 Sedan
# 9969  Perfect inside and out      Dealer             Crossover
#
#      no_of_cylinders       transmission_type        regional_specs  \
# 0                  6  Automatic Transmission             GCC Specs
# 1                  8  Automatic Transmission  North American Specs
# 2                  6  Automatic Transmission             GCC Specs
# 3                  8  Automatic Transmission             GCC Specs
# 4                  4     Manual Transmission             GCC Specs
# ...              ...                     ...                   ...
# 9965               8  Automatic Transmission             GCC Specs
# 9966               8  Automatic Transmission             GCC Specs
# 9967               8  Automatic Transmission                 Other
# 9968               4  Automatic Transmission             GCC Specs
# 9969               6     Manual Transmission             GCC Specs
#
#       horsepower fuel_type    year   color   emirate        company  \
# 0          350.0  Gasoline  2013.0  Silver     Dubai     mitsubishi
# 1          450.0  Gasoline  2018.0   White   Sharjah      chevrolet
# 2          450.0  Gasoline  2014.0    Blue   Sharjah  mercedes-benz
# 3          650.0  Gasoline  2018.0     Red     Dubai        ferrari
# 4           75.0  Gasoline  2020.0   White     Dubai        renault
# ...          ...       ...     ...     ...       ...            ...
# 9965       550.0  Gasoline  2015.0   White     Dubai     land-rover
# 9966       450.0  Gasoline  2014.0   White     Dubai       cadillac
# 9967       450.0  Gasoline     NaN   Black     Dubai     land-rover
# 9968       175.0  Gasoline  2013.0   White     Dubai      chevrolet
# 9969       250.0  Gasoline  2013.0  Orange     Dubai           jeep
#
#      date_posted
# 0      13/05/2022
# 1      14/01/2022
# 2      05/05/2022
# 3      30/04/2022
# 4      13/05/2022
# ...           ...
# 9965   18/11/2021
# 9966   11/05/2022
# 9967   14/12/2021
# 9968   06/03/2022
# 9969   04/12/2021
#
# [9970 rows x 16 columns]

# %%
string_columns_in_processed_X = X_processed.select_dtypes(include='object').columns.tolist()

if string_columns_in_processed_X:
    print(f"\n경고: X_processed에 다음 문자열(object) 타입 컬럼이 남아있습니다 ({len(string_columns_in_processed_X)}개):")
    for col in string_columns_in_processed_X:
        print(f"- '{col}' (샘플 값: {X_processed[col].iloc[0]})") # 첫 번째 값도 함께 출력
    print("\n선형 회귀 모델은 문자열 데이터를 처리할 수 없으므로, 이 컬럼들을 추가 전처리해야 합니다.")
else:
    print("\n알림: X_processed에 문자열(object) 타입 컬럼이 없습니다. 모든 특성이 숫자형입니다.")
# Out:
# 알림: X_processed에 문자열(object) 타입 컬럼이 없습니다. 모든 특성이 숫자형입니다.

# %%
# --- 디버깅: train_test_split 직전 X_processed의 결측치 확인 ---
print("\n--- 디버깅: train_test_split 직전 X_processed의 결측치 개수 ---")
nan_counts = X_processed.isnull().sum()
print(nan_counts[nan_counts > 0]) # NaN이 있는 컬럼만 출력

if nan_counts.sum() > 0:
    print("\n경고: X_processed에 결측치(NaN)가 남아있습니다. 모델 훈련 전에 처리해야 합니다.")
    # 결측치 처리 (SimpleImputer)를 다시 적용하거나, ColumnTransformer가 제대로 적용되었는지 확인해야 합니다.
    # 가장 간단한 방법은 전체 X_processed에 대해 SimpleImputer를 다시 적용하는 것입니다.
    from sklearn.impute import SimpleImputer
    imputer_final = SimpleImputer(strategy='median')
    # 모든 수치형 컬럼에 대해 imputer 적용
    # 주의: X_processed에 문자열 컬럼이 있다면 오류가 발생할 수 있습니다.
    #       이전 단계에서 모든 문자열이 숫자형으로 변환되었어야 합니다.
    numerical_cols_in_X_processed = X_processed.select_dtypes(include=np.number).columns
    X_processed[numerical_cols_in_X_processed] = imputer_final.fit_transform(X_processed[numerical_cols_in_X_processed])
    print("\n알림: X_processed의 남은 결측치를 중앙값으로 채웠습니다.")
    print("--- 결측치 채운 후 X_processed의 결측치 개수 ---")
    print(X_processed.isnull().sum()[X_processed.isnull().sum() > 0])
else:
    print("\n알림: X_processed에 결측치(NaN)가 없습니다. 모델 훈련을 진행합니다.")
# Out:
# --- 디버깅: train_test_split 직전 X_processed의 결측치 개수 ---
# year           970
# age_at_post    970
# dtype: int64
#
# 경고: X_processed에 결측치(NaN)가 남아있습니다. 모델 훈련 전에 처리해야 합니다.
#
# 알림: X_processed의 남은 결측치를 중앙값으로 채웠습니다.
# --- 결측치 채운 후 X_processed의 결측치 개수 ---
# Series([], dtype: int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=156)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

# 예측
y_pred = lr.predict(X_test)
print(y_pred[:3])
# Out:
# [ 82522.25964367 579666.2114456  128454.79061133]

# %%
mse = mean_squared_error(y_test, y_pred)
rmse= np.sqrt(mse)
mse, rmse
# Out:
# (np.float64(147743269256.17212), np.float64(384373.86651042255))

# %%
r2_score(y_test, y_pred)
# Out:
# np.float64(0.5102582177359831)

# %%
evals = [(X_test, y_test)]
xgb = XGBRegressor(n_estimators=400, learning_rate=0.1, max_depth=3, use_label_encoder=False)
xgb.fit(X_train, y_train,  eval_set=evals, verbose=True)
xgb_pred = xgb.predict(X_test)
# Out:
# [0]	validation_0-rmse:576471.51329
# [1]	validation_0-rmse:549505.02059
# [2]	validation_0-rmse:525534.86337
# [3]	validation_0-rmse:506008.01677
# [4]	validation_0-rmse:488031.25104
# [5]	validation_0-rmse:472359.35633
# [6]	validation_0-rmse:458083.89907
# [7]	validation_0-rmse:447326.47562
# [8]	validation_0-rmse:434462.90950
# [9]	validation_0-rmse:425194.73644
# [10]	validation_0-rmse:418019.84098
# [11]	validation_0-rmse:408926.07775
# [12]	validation_0-rmse:403041.71838
# [13]	validation_0-rmse:398411.52438
# [14]	validation_0-rmse:393457.73228
# [15]	validation_0-rmse:388715.45979
# [16]	validation_0-rmse:384240.22403
# [17]	validation_0-rmse:380886.59258
# [18]	validation_0-rmse:375910.49280
# [19]	validation_0-rmse:373084.20694
# [20]	validation_0-rmse:371183.97784
# [21]	validation_0-rmse:369365.51038
# [22]	validation_0-rmse:362857.40990
# [23]	validation_0-rmse:360777.62537
# [24]	validation_0-rmse:358800.38646
# [25]	validation_0-rmse:357610.84590
# [26]	validation_0-rmse:356764.66679
# [27]	validation_0-rmse:355213.23966
# [28]	validation_0-rmse:354214.37100
# [29]	validation_0-rmse:353051.87488
# [30]	validation_0-rmse:352368.86925
# [31]	validation_0-rmse:351391.84535
# [32]	validation_0-rmse:350810.28794
# [33]	validation_0-rmse:350007.30586
# [34]	validation_0-rmse:349615.92216
# [35]	validation_0-rmse:349138.58453
# [36]	validation_0-rmse:348477.63625
# [37]	validation_0-rmse:345657.26937
# [38]	validation_0-rmse:345275.96893
# [39]	validation_0-rmse:344814.47927
# [40]	validation_0-rmse:344443.83919
# [41]	validation_0-rmse:343990.74163
# [42]	validation_0-rmse:342640.10374
# [43]	validation_0-rmse:339532.99972
# [44]	validation_0-rmse:339341.59972
# [45]	validation_0-rmse:339101.38312
# [46]	validation_0-rmse:338997.17729
# [47]	validation_0-rmse:338527.38255
# [48]	validation_0-rmse:338128.41402
# [49]	validation_0-rmse:337812.95889
# [50]	validation_0-rmse:337357.93767
# [51]	validation_0-rmse:335590.49552
# [52]	validation_0-rmse:335347.89739
# [53]	validation_0-rmse:335321.81568
# [54]	validation_0-rmse:335114.67836
# [55]	validation_0-rmse:334829.04289
# [56]	validation_0-rmse:334552.24173
# [57]	validation_0-rmse:334330.99268
# [58]	validation_0-rmse:334212.72022
# [59]	validation_0-rmse:334727.19847
# [60]	validation_0-rmse:334527.20503
# [61]	validation_0-rmse:334374.37325
# [62]	validation_0-rmse:334193.94070
# [63]	validation_0-rmse:333691.65544
# [64]	validation_0-rmse:334394.46788
# [65]	validation_0-rmse:334186.65304
# [66]	validation_0-rmse:333840.74302
# [67]	validation_0-rmse:333970.46785
# [68]	validation_0-rmse:333793.71567
# [69]	validation_0-rmse:334134.12420
# [70]	validation_0-rmse:334049.09519
# [71]	validation_0-rmse:333514.10770
# [72]	validation_0-rmse:333329.76487
# [73]	validation_0-rmse:333032.22267
# [74]	validation_0-rmse:332963.45703
# [75]	validation_0-rmse:332768.87501
# [76]	validation_0-rmse:332605.12260
# [77]	validation_0-rmse:333081.76851
# [78]	validation_0-rmse:332973.89004
# [79]	validation_0-rmse:332932.41216
# [80]	validation_0-rmse:333485.52017
# [81]	validation_0-rmse:333960.03836
# [82]	validation_0-rmse:333849.67272
# [83]	validation_0-rmse:333635.24506
# [84]	validation_0-rmse:333532.14958
# [85]	validation_0-rmse:333439.88265
# [86]	validation_0-rmse:333634.10826
# [87]	validation_0-rmse:333110.88164
# [88]	validation_0-rmse:333027.43026
# [89]	validation_0-rmse:333017.70843
# [90]	validation_0-rmse:333442.47004
# [91]	validation_0-rmse:333399.32391
# [92]	validation_0-rmse:333290.88418
# [93]	validation_0-rmse:333247.02745
# [94]	validation_0-rmse:333713.50592
# [95]	validation_0-rmse:333646.32749
# [96]	validation_0-rmse:333470.58134
# [97]	validation_0-rmse:333413.86322
# [98]	validation_0-rmse:333286.65721
# [99]	validation_0-rmse:333249.12576
# [100]	validation_0-rmse:333191.82144
# [101]	validation_0-rmse:332977.20420
# [102]	validation_0-rmse:332958.34456
# [103]	validation_0-rmse:333341.82788
# [104]	validation_0-rmse:333680.32383
# [105]	validation_0-rmse:333614.89531
# [106]	validation_0-rmse:333592.88320
# [107]	validation_0-rmse:333346.85401
# [108]	validation_0-rmse:333342.15210
# [109]	validation_0-rmse:333285.87977
# [110]	validation_0-rmse:333494.15870
# [111]	validation_0-rmse:333345.89624
# [112]	validation_0-rmse:333309.01414
# [113]	validation_0-rmse:333281.34981
# [114]	validation_0-rmse:333207.02622
# [115]	validation_0-rmse:333180.89074
# [116]	validation_0-rmse:333091.26614
# [117]	validation_0-rmse:333033.53450
# [118]	validation_0-rmse:331741.56400
# [119]	validation_0-rmse:331707.07696
# [120]	validation_0-rmse:331670.57885
# [121]	validation_0-rmse:331697.04855
# [122]	validation_0-rmse:331641.26093
# [123]	validation_0-rmse:331491.49236
# [124]	validation_0-rmse:331353.54363
# [125]	validation_0-rmse:331367.64077
# [126]	validation_0-rmse:331346.80092
# [127]	validation_0-rmse:331335.35485
# [128]	validation_0-rmse:331306.20793
# [129]	validation_0-rmse:331203.96156
# [130]	validation_0-rmse:331172.72902
# [131]	validation_0-rmse:331176.27829
# [132]	validation_0-rmse:331165.50372
# [133]	validation_0-rmse:331149.06749
# [134]	validation_0-rmse:331152.37864
# [135]	validation_0-rmse:331001.46932
# [136]	validation_0-rmse:330875.86759
# [137]	validation_0-rmse:330855.27311
# [138]	validation_0-rmse:330850.32289
# [139]	validation_0-rmse:330813.39810
# [140]	validation_0-rmse:330799.84622
# [141]	validation_0-rmse:330793.28384
# [142]	validation_0-rmse:330764.19032
# [143]	validation_0-rmse:330734.13748
# [144]	validation_0-rmse:330751.19645
# [145]	validation_0-rmse:330702.84274
# [146]	validation_0-rmse:330716.93350
# [147]	validation_0-rmse:330347.62117
# [148]	validation_0-rmse:330341.60657
# [149]	validation_0-rmse:330321.67367
# [150]	validation_0-rmse:330296.56902
# [151]	validation_0-rmse:330297.09187
# [152]	validation_0-rmse:330266.32084
# [153]	validation_0-rmse:330250.36037
# [154]	validation_0-rmse:330211.83913
# [155]	validation_0-rmse:330201.20307
# [156]	validation_0-rmse:330184.54584
# [157]	validation_0-rmse:330194.58611
# [158]	validation_0-rmse:330204.33827
# [159]	validation_0-rmse:330831.47428
# [160]	validation_0-rmse:330839.64183
# [161]	validation_0-rmse:330709.31739
# [162]	validation_0-rmse:330698.57918
# [163]	validation_0-rmse:330690.47195
# [164]	validation_0-rmse:330685.98211
# [165]	validation_0-rmse:331302.26885
# [166]	validation_0-rmse:331230.42315
# [167]	validation_0-rmse:331237.40248
# [168]	validation_0-rmse:330938.80237
# [169]	validation_0-rmse:331306.68727
# [170]	validation_0-rmse:331260.89722
# [171]	validation_0-rmse:331243.78045
# [172]	validation_0-rmse:331249.37795
# [173]	validation_0-rmse:331228.38725
# [174]	validation_0-rmse:331191.23391
# [175]	validation_0-rmse:330217.78974
# [176]	validation_0-rmse:330206.97015
# [177]	validation_0-rmse:330197.71609
# [178]	validation_0-rmse:330040.70381
# [179]	validation_0-rmse:330042.39955
# [180]	validation_0-rmse:330001.28305
# [181]	validation_0-rmse:330026.72405
# [182]	validation_0-rmse:329992.61927
# [183]	validation_0-rmse:329999.64345
# [184]	validation_0-rmse:330175.95035
# [185]	validation_0-rmse:330166.15342
# [186]	validation_0-rmse:330141.59358
# [187]	validation_0-rmse:330338.25744
# [188]	validation_0-rmse:330360.91073
# [189]	validation_0-rmse:330297.95219
# [190]	validation_0-rmse:330264.04447
# [191]	validation_0-rmse:330262.63092
# [192]	validation_0-rmse:330275.08575
# [193]	validation_0-rmse:330265.93380
# [194]	validation_0-rmse:330272.19537
# [195]	validation_0-rmse:330155.13757
# [196]	validation_0-rmse:330144.57538
# [197]	validation_0-rmse:330146.63372
# [198]	validation_0-rmse:330130.72435
# [199]	validation_0-rmse:330137.92618
# [200]	validation_0-rmse:330112.53379
# [201]	validation_0-rmse:330109.41719
# [202]	validation_0-rmse:329973.97595
# [203]	validation_0-rmse:329940.47965
# [204]	validation_0-rmse:329932.46619
# [205]	validation_0-rmse:329940.00074
# [206]	validation_0-rmse:329910.34592
# [207]	validation_0-rmse:329767.54403
# [208]	validation_0-rmse:329734.94258
# [209]	validation_0-rmse:329713.44566
# [210]	validation_0-rmse:329727.79630
# [211]	validation_0-rmse:329737.45506
# [212]	validation_0-rmse:329682.40871
# [213]	validation_0-rmse:329674.66423
# [214]	validation_0-rmse:329671.41472
# [215]	validation_0-rmse:329651.45428
# [216]	validation_0-rmse:329626.60191
# [217]	validation_0-rmse:329479.60919
# [218]	validation_0-rmse:329369.77623
# [219]	validation_0-rmse:329810.64515
# [220]	validation_0-rmse:329747.03112
# [221]	validation_0-rmse:329744.43922
# [222]	validation_0-rmse:329766.77532
# [223]	validation_0-rmse:329774.32347
# [224]	validation_0-rmse:329863.93517
# [225]	validation_0-rmse:329845.61695
# [226]	validation_0-rmse:329865.15715
# [227]	validation_0-rmse:329803.03250
# [228]	validation_0-rmse:329723.65227
# [229]	validation_0-rmse:329717.46041
# [230]	validation_0-rmse:329724.27030
# [231]	validation_0-rmse:329717.58955
# [232]	validation_0-rmse:329715.50573
# [233]	validation_0-rmse:329691.09637
# [234]	validation_0-rmse:329665.13677
# [235]	validation_0-rmse:329638.95197
# [236]	validation_0-rmse:329676.66175
# [237]	validation_0-rmse:329632.99967
# [238]	validation_0-rmse:329593.63241
# [239]	validation_0-rmse:329604.91912
# [240]	validation_0-rmse:329354.33469
# [241]	validation_0-rmse:329349.96336
# [242]	validation_0-rmse:329355.52605
# [243]	validation_0-rmse:329383.00042
# [244]	validation_0-rmse:329408.43027
# [245]	validation_0-rmse:329179.42753
# [246]	validation_0-rmse:329167.97864
# [247]	validation_0-rmse:329167.81789
# [248]	validation_0-rmse:329051.32100
# [249]	validation_0-rmse:329037.63651
# [250]	validation_0-rmse:329033.64473
# [251]	validation_0-rmse:328988.56065
# [252]	validation_0-rmse:328993.89317
# [253]	validation_0-rmse:328988.07122
# [254]	validation_0-rmse:328978.96581
# [255]	validation_0-rmse:329011.03505
# [256]	validation_0-rmse:328966.94287
# [257]	validation_0-rmse:328957.20720
# [258]	validation_0-rmse:329516.06872
# [259]	validation_0-rmse:329514.25809
# [260]	validation_0-rmse:329516.62135
# [261]	validation_0-rmse:329509.21546
# [262]	validation_0-rmse:329409.53379
# [263]	validation_0-rmse:329743.15551
# [264]	validation_0-rmse:329740.61436
# [265]	validation_0-rmse:329708.10648
# [266]	validation_0-rmse:329703.90956
# [267]	validation_0-rmse:329694.65173
# [268]	validation_0-rmse:329694.41102
# [269]	validation_0-rmse:329689.74479
# [270]	validation_0-rmse:329646.07008
# [271]	validation_0-rmse:329651.17260
# [272]	validation_0-rmse:329673.97653
# [273]	validation_0-rmse:329632.47919
# [274]	validation_0-rmse:329636.37451
# [275]	validation_0-rmse:329480.41367
# [276]	validation_0-rmse:329986.66398
# [277]	validation_0-rmse:330068.12301
# [278]	validation_0-rmse:330058.03451
# [279]	validation_0-rmse:330056.33974
# [280]	validation_0-rmse:329938.18916
# [281]	validation_0-rmse:329912.59079
# [282]	validation_0-rmse:329845.47052
# [283]	validation_0-rmse:329757.57953
# [284]	validation_0-rmse:329763.03012
# [285]	validation_0-rmse:329762.11586
# [286]	validation_0-rmse:329762.42462
# [287]	validation_0-rmse:329760.78788
# [288]	validation_0-rmse:329778.35717
# [289]	validation_0-rmse:329756.48261
# [290]	validation_0-rmse:329924.08796
# [291]	validation_0-rmse:329968.65811
# [292]	validation_0-rmse:329938.89256
# [293]	validation_0-rmse:329960.13302
# [294]	validation_0-rmse:329948.87340
# [295]	validation_0-rmse:329936.44450
# [296]	validation_0-rmse:329906.71066
# [297]	validation_0-rmse:329892.45779
# [298]	validation_0-rmse:329888.97607
# [299]	validation_0-rmse:329886.72099
# [300]	validation_0-rmse:329761.29769
# [301]	validation_0-rmse:329825.90622
# [302]	validation_0-rmse:329819.13973
# [303]	validation_0-rmse:329827.09181
# [304]	validation_0-rmse:329813.47473
# [305]	validation_0-rmse:329817.95012
# [306]	validation_0-rmse:329803.14047
# [307]	validation_0-rmse:329792.40139
# [308]	validation_0-rmse:329782.79414
# [309]	validation_0-rmse:329777.89302
# [310]	validation_0-rmse:329752.16314
# [311]	validation_0-rmse:329750.15502
# [312]	validation_0-rmse:329743.13996
# [313]	validation_0-rmse:329756.66554
# [314]	validation_0-rmse:329760.43309
# [315]	validation_0-rmse:329765.67926
# [316]	validation_0-rmse:330117.27551
# [317]	validation_0-rmse:329972.17768
# [318]	validation_0-rmse:329371.26165
# [319]	validation_0-rmse:329375.32198
# [320]	validation_0-rmse:329401.21818
# [321]	validation_0-rmse:329430.22176
# [322]	validation_0-rmse:330362.12936
# [323]	validation_0-rmse:330158.67716
# [324]	validation_0-rmse:330156.98323
# [325]	validation_0-rmse:330146.52088
# [326]	validation_0-rmse:330144.22133
# [327]	validation_0-rmse:330166.72848
# [328]	validation_0-rmse:330199.98567
# [329]	validation_0-rmse:330334.97218
# [330]	validation_0-rmse:330313.13104
# [331]	validation_0-rmse:330320.96260
# [332]	validation_0-rmse:330314.81362
# [333]	validation_0-rmse:330307.36872
# [334]	validation_0-rmse:330313.62427
# [335]	validation_0-rmse:330313.82820
# [336]	validation_0-rmse:330158.95355
# [337]	validation_0-rmse:330161.83228
# [338]	validation_0-rmse:330172.47689
# [339]	validation_0-rmse:330203.78836
# [340]	validation_0-rmse:330206.46339
# [341]	validation_0-rmse:330210.70721
# [342]	validation_0-rmse:330210.57946
# [343]	validation_0-rmse:330187.77691
# [344]	validation_0-rmse:330164.85926
# [345]	validation_0-rmse:330164.87993
# [346]	validation_0-rmse:330161.16393
# [347]	validation_0-rmse:330158.28266
# [348]	validation_0-rmse:330155.56619
# [349]	validation_0-rmse:330120.38319
# [350]	validation_0-rmse:330111.10862
# [351]	validation_0-rmse:329994.14903
# [352]	validation_0-rmse:329990.28494
# [353]	validation_0-rmse:329994.35563
# [354]	validation_0-rmse:329970.82490
# [355]	validation_0-rmse:330195.54073
# [356]	validation_0-rmse:330196.85795
# [357]	validation_0-rmse:330191.65790
# [358]	validation_0-rmse:330202.77158
# [359]	validation_0-rmse:330214.39202
# [360]	validation_0-rmse:330181.53676
# [361]	validation_0-rmse:330182.62003
# [362]	validation_0-rmse:330164.17342
# [363]	validation_0-rmse:330119.78911
# [364]	validation_0-rmse:330063.17188
# [365]	validation_0-rmse:330061.64160
# [366]	validation_0-rmse:330041.06260
# [367]	validation_0-rmse:329925.66131
# [368]	validation_0-rmse:329908.67424
# [369]	validation_0-rmse:329921.11413
# [370]	validation_0-rmse:329982.15796
# [371]	validation_0-rmse:329972.94049
# [372]	validation_0-rmse:329941.99464
# [373]	validation_0-rmse:329561.49223
# [374]	validation_0-rmse:329669.90354
# [375]	validation_0-rmse:329659.15359
# [376]	validation_0-rmse:329629.22820
# [377]	validation_0-rmse:329641.86610
# [378]	validation_0-rmse:329605.77867
# [379]	validation_0-rmse:329597.91468
# [380]	validation_0-rmse:329586.33446
# [381]	validation_0-rmse:329558.59107
# [382]	validation_0-rmse:329563.32439
# [383]	validation_0-rmse:329565.26815
# [384]	validation_0-rmse:329559.10530
# [385]	validation_0-rmse:329562.54308
# [386]	validation_0-rmse:329561.41868
# [387]	validation_0-rmse:329559.73195
# [388]	validation_0-rmse:329559.01440
# [389]	validation_0-rmse:329571.11472
# [390]	validation_0-rmse:329566.96151
# [391]	validation_0-rmse:329581.11148
# [392]	validation_0-rmse:329530.94256
# [393]	validation_0-rmse:329524.12843
# [394]	validation_0-rmse:329524.78489
# [395]	validation_0-rmse:329520.07683
# [396]	validation_0-rmse:329539.34251
# [397]	validation_0-rmse:329534.19203
# [398]	validation_0-rmse:329525.41129
# [399]	validation_0-rmse:329575.26434

# %%
xgb_pred[:3]
# Out:
# array([ 98949.75, 558123.94, 211960.95], dtype=float32)

# %%
mse = mean_squared_error(y_test, xgb_pred)
rmse= np.sqrt(mse)
mse, rmse
# Out:
# (np.float64(108619851045.9352), np.float64(329575.25854641333))

# %%
r2_score(y_test, xgb_pred)
# Out:
# np.float64(0.6399451581902366)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_processed, y, test_size=0.2, random_state=156)

# %%
rf = RandomForestRegressor(random_state=100, max_depth=3)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
y_pred[:3]
# Out:
# array([ 89302.144331  , 416162.90271688, 236131.24973528])

# %%
mse = mean_squared_error(y_test, y_pred)
rmse= np.sqrt(mse)
mse, rmse
# Out:
# (np.float64(156683585049.20377), np.float64(395832.7740968448))

# %%
r2_score(y_test, y_pred)
# Out:
# np.float64(0.48062271411861923)

# %%
r2_scores= cross_val_score(rf, X_processed, y, scoring='r2', cv=5)
r2_scores, np.mean(r2_scores)
# Out:
# (array([0.6071816 , 0.63693333, 0.45794819, 0.63774515, 0.7460201 ]),
#  np.float64(0.6171656758802064))

# %%
results = []

X_train, X_test, y_train, y_test = train_test_split(X_processed,y, test_size=0.3, random_state=42)

# %%
for degree in range(1,2):
  model_poly = Pipeline([
    ('poly', PolynomialFeatures(degree=degree, include_bias=False)),
    ('linear', LinearRegression())]
  )
  model_poly.fit(X_train, y_train)
  pred_poly = model_poly.predict(X_test)
  mse = mean_squared_error(y_test, pred_poly)
  rmse = np.sqrt(mse)
  r2 = r2_score(y_test, pred_poly)
  
  results.append({ 'degree':degree,
                  'MSE':mse,
                  'RMSE':rmse,
                  'R2': r2})

pd.DataFrame(results)
# Out:
#    degree           MSE           RMSE       R2
# 0       1  1.176364e+11  342981.598722  0.53342

# %%
r2_score(y_test, pred_poly)
# Out:
# np.float64(0.5334202916163552)

# %% [markdown]
# # 다항연산

# %%
ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)
pred_ridge = ridge.predict(X_test)

mse = mean_squared_error(y_test, pred_ridge)
r2  = r2_score(y_test, pred_ridge)
mse, r2
# Out:
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=6.69733e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# (np.float64(117919712831.01497), np.float64(0.5322965004569333))

# %%
alphas = [0.001, 0.01, 0.1, 1, 10, 100]
ridge_cv = RidgeCV(alphas=alphas, cv=5)

# %%
ridge_cv.fit(X_train, y_train)
ridge_preds = ridge_cv.predict(X_test)
# Out:
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=2.47238e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.54695e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.54529e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.54685e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.54759e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.53105e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.51712e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.51829e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.52256e-19): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.39225e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.27449e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.27446e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.30679e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=6.98156e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=6.3954e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=6.46607e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=6.58092e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=7.54104e-20): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
ridge_mse = mean_squared_error(y_test, ridge_preds)
ridge_r2 = r2_score(y_test, ridge_preds)
print(f'ridge cv mse: {ridge_mse:4f}, r2 : {ridge_r2:4f}')
# Out:
# ridge cv mse: 117636578145.366928, r2 : 0.533419

# %% [markdown]
# # 릿지

# %%
lasso = Lasso(alpha=0.1)  # alpha 값 작으면 규제 약해짐
lasso.fit(X_train, y_train)
pred_lasso = lasso.predict(X_test)

print("\n[라쏘 회귀]")
print("MSE:", mean_squared_error(y_test, pred_lasso))
print("R2:", r2_score(y_test, pred_lasso))
# Out:
# [라쏘 회귀]
# MSE: 118004248028.54175
# R2: 0.531961209547817
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.021e+14, tolerance: 1.298e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
lasso_cv = LassoCV(alphas=alphas, cv=5, max_iter=10000)
lasso_cv.fit(X_train, y_train)
lasso_preds = lasso_cv.predict(X_test)
lasso_mse = mean_squared_error(y_test, lasso_preds)
lasso_r2 = r2_score(y_test, lasso_preds)
# Out:
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26223654645575.22, tolerance: 107552282513.58269
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125883126590091.05, tolerance: 107552282513.58269
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134002365671143.75, tolerance: 107552282513.58269
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 132331089734125.6, tolerance: 107552282513.58269
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 131949261386456.69, tolerance: 107552282513.58269
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 131854150931816.0, tolerance: 107552282513.58269
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2544518741013.25, tolerance: 108766088102.01654
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 140981989809203.62, tolerance: 108766088102.01654
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152989183400574.2, tolerance: 108766088102.01654
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 156410063556139.22, tolerance: 108766088102.01654
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157185326967828.03, tolerance: 108766088102.01654
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 157384459624926.22, tolerance: 108766088102.01654
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48014121622475.09, tolerance: 99241227478.36687
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 136340259517669.67, tolerance: 99241227478.36687
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137785218144420.1, tolerance: 99241227478.36687
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138292544353654.73, tolerance: 99241227478.36687
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138540099383882.67, tolerance: 99241227478.36687
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138677655402372.05, tolerance: 99241227478.36687
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8247984886115.406, tolerance: 99794646606.95302
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36225205440392.5, tolerance: 99794646606.95302
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 137773935795115.98, tolerance: 99794646606.95302
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 139241851448276.98, tolerance: 99794646606.95302
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 139758454140805.89, tolerance: 99794646606.95302
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 139951847123486.4, tolerance: 99794646606.95302
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45981043803805.59, tolerance: 103633690129.40898
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 159157589043962.62, tolerance: 103633690129.40898
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 160876175200418.97, tolerance: 103633690129.40898
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161251796835406.06, tolerance: 103633690129.40898
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161454885766942.44, tolerance: 103633690129.40898
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:664: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161534567210415.78, tolerance: 103633690129.40898
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.976e+14, tolerance: 1.298e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
print(f"[개선 Lasso] 최적 alpha: {lasso_cv.alpha_}")
print(f"MSE: {lasso_mse:.3f}, R2: {lasso_r2:.3f}")
# Out:
# [개선 Lasso] 최적 alpha: 10.0
# MSE: 117616884570.052, R2: 0.533

# %% [markdown]
# # 로쏘회귀

# %%
enet = ElasticNet(alpha=0.1, l1_ratio=0.5)
enet.fit(X_train, y_train)
# Out:
# c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.292e+14, tolerance: 1.298e+11
#   model = cd_fast.enet_coordinate_descent(
# ElasticNet(alpha=0.1)

# %%
enet_pred = enet.predict(X_test)
print("\n[엘라스틱넷 회귀]")
print("MSE:", mean_squared_error(y_test, enet_pred))
print("R2:", r2_score(y_test, enet_pred))
# Out:
# [엘라스틱넷 회귀]
# MSE: 147004874729.11743
# R2: 0.4169363823059221
