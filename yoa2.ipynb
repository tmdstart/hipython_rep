# %%
import time
  #################메뉴리스트정의
menu_list = [ 
    {'name': '요거트 아이스크림', 'price': 3000},
    {'name': '바나나', 'price': 4000},
    {'name': '딸기', 'price': 5000},
    {'name': '벌집꿀', 'price': 7000},
    {'name': '그레놀라', 'price': 7000},
    {'name': '초코쉘', 'price': 7000},
]
num_order= 1
final_break = False
while True:
    ######################################초기화면 (메뉴판)################################################
    print('*'*40)
    print(f'어서오세요 {num_order}번째 손님, ‘요렇게’에 오신것을 환영합니다:)\n')
    
    print("Menu\t\t\tPrice")
    print("-" * 30)
    print("요거트 아이스크림(250g)\t3,000")
    print("-" * 30)
    
    print("\nNo.  Topping\t\tPrice")
    print("-" * 30)
    for idx, item in enumerate(menu_list, start=1):
        print(f"{idx:<5} {item['name']:<10}\t{item['price']:,}")
    print("-" * 30)
    print("*" * 40)
    
    ##############기본 상품(요거트 아이스크림) 장바구니에 자동추가
    cart = []
    default_item = menu_list[0]
    cart.append({'name': default_item['name'], 'price': default_item['price'], 'quantity': 1})
    total_price = 3000
    cancle = False
    ##############3장바구니 관리 루프 시작
    while True:
       #########장바구니 출력
        print("\n" + "=" * 40)
        print("현재 장바구니")
        for i, item in enumerate(cart, start=1):
            print(f"{i}. {item['name']} x {item['quantity']} = {item['price'] * item['quantity']:,}원")
        print("-" * 40)
        print(f"Total = {total_price:,}원")
      ##########메뉴선택안내
        print("메뉴를 확정하려면 1")
        print("메뉴를 삭제하려면 2")
        print("메뉴를 추가하려면 3")
        print("메뉴를 취소하려면 4")
        ############################# 99번 입력 시 무한루프 끝 #####################################
        select = int(input("번호를 입력해주세요 : "))
        ####################[2-1]주문 확정
        if select == 1:
            break
        ####################[2-2]메뉴 삭제
        elif select == 2:
           #################삭제할 메뉴 번호 입력받고 수량 삭제 처리
            print("\n" + "=" * 40)
            print("현재 장바구니")
            for i, item in enumerate(cart, start=1):
                print(f"{i}. {item['name']} x {item['quantity']} = {item['price'] * item['quantity']:,}원")
            print("-" * 40)
            print(f"Total = {total_price:,}원")
        
            del_no = int(input("삭제할 메뉴의 번호를 골라주세요 : ")) - 1
            if 0 <= del_no < len(cart):
                item = cart[del_no]
                print(f"'{item['name']}'의 현재 수량: {item['quantity']}")
                del_qty = int(input("몇 개를 삭제하시겠습니까? : "))
        
                if del_qty >= item['quantity'] or del_qty <= 0:
                    # 전체 삭제
                    total_price -= item["price"] * item["quantity"]
                    cart.pop(del_no)
                    print(f"'{item['name']}' 전체가 장바구니에서 삭제되었습니다.")
                else:
                    # 일부 수량만 삭제
                    item['quantity'] -= del_qty
                    total_price -= item["price"] * del_qty
                    print(f"'{item['name']}' {del_qty}개가 삭제되었습니다.")
        
            else:
                print("올바른 번호를 입력하세요.")
        
            print("\n" + "=" * 40)
            print("현재 장바구니")
            for i, item in enumerate(cart, start=1):
                print(f"{i}. {item['name']} x {item['quantity']} = {item['price'] * item['quantity']:,}원")
            print("-" * 40)
            print(f"Total = {total_price:,}원")
    ############################# [2-3] 메뉴 추가
        elif select == 3:
     ######################## 메뉴 리스트 보여주고 선택한 토핑 추가
            print("\n메뉴 목록:")
            for i, item in enumerate(menu_list, start=1):
                print(f"{i}. {item['name']} : {item['price']:,}원")
            add_topping = int(input('추가할 토핑 번호를 골라주세요 :')) - 1
            qty = int(input('수량을 선택해주세요 : '))
    
            selected_item = menu_list[add_topping]
            found = False
    
            for item in cart:
                if item['name'] == selected_item['name']:
                    item['quantity'] += qty
                    found = True
                    break
                    
            if not found:
                cart.append({'name': selected_item['name'], 'quantity': qty, 'price': selected_item['price']})
    
            total_price += selected_item['price'] * qty
    
            print("\n" + "=" * 40)
            print("현재 장바구니")
            for i, item in enumerate(cart, start=1):
                print(f"{i}. {item['name']} x {item['quantity']} = {item['price'] * item['quantity']:,}원")
            print("-" * 40)
            print(f"Total = {total_price:,}원")
       ###############[2-4]주문 취소
        elif select == 4:
            print("주문이 취소됩니다.")
            cancle = True
            break
        ################# [2-5] 프로그램 종료 명령어
        elif select == 99:

                print("\n관리자 모드에 접속합니다.")
        
        while True:
            print("\n[관리자 기능]")
            print("1. 메뉴 추가")
            print("2. 메뉴 삭제")
            print("3. 관리자 모드 종료")
            
            admin_choice = int(input("번호를 입력해주세요: "))
            
            if admin_choice == 1:
                # 메뉴 추가 기능
                new_name = input("추가할 메뉴 이름을 입력하세요: ")
                new_price = int(input("가격을 입력하세요: "))
                menu_list.append({'name': new_name, 'price': new_price})
                print(f"'{new_name}'(가격: {new_price:,}원)이 메뉴에 추가되었습니다.")
            
            elif admin_choice == 2:
                # 메뉴 삭제 기능
                print("\n현재 메뉴 목록:")
                for i, item in enumerate(menu_list, start=1):
                    print(f"{i}. {item['name']} : {item['price']:,}원")
                
                del_menu = int(input("삭제할 메뉴 번호를 선택하세요: ")) - 1
                if 0 <= del_menu < len(menu_list):
                    removed_item = menu_list.pop(del_menu)
                    print(f"'{removed_item['name']}'이 삭제되었습니다.")
                else:
                    print("올바른 번호를 입력하세요.")
            
            elif admin_choice == 3:
                print("관리자 모드를 종료합니다.")
                break
            
            else:
                print("올바른 번호를 입력하세요.")


            
            print("관리자 중지입니다.")
            final_break = True
            break
    ################[3] 외부 루프 종료 조건
    if final_break:
        break
   
    ################# [4] 주문 취소 시 초기화면으로 복귀
    if cancle:
        print("초기화면으로 돌아갑니다.")
        for i in range(5, 0, -1):
            print(f"{i}   ", end='\r', flush=True)
            time.sleep(1)
        print("   ", end='\r' )
        continue
   ###################### [5] 결제 여부 확인  
    pay = input("주문이 확정되었습니다. 결제를 하시겠습니까? (y/n)")
    if pay == 'y':
        print(f"{total_price:,}원 결제하겠습니다. 카드를 삽입해주세요.")
        print("결제가 완료되었습니다.")
        num_order +=1
        print("초기화면으로 돌아갑니다.")
        for i in range(5, 0, -1):
            print(f"{i}   ", end='\r', flush=True)
            time.sleep(1)
        print("   ", end='\r' )
        continue
    else:
        print("초기화면으로 돌아갑니다.")
        for i in range(5, 0, -1):
            print(f"{i}   ", end='\r', flush=True)
            time.sleep(1)
        print("   ", end='\r' )
        continue
# Out:
# ****************************************
# 어서오세요 1번째 손님, ‘요렇게’에 오신것을 환영합니다:)
#
# Menu			Price
# ------------------------------
# 요거트 아이스크림(250g)	3,000
# ------------------------------
#
# No.  Topping		Price
# ------------------------------
# 1     요거트 아이스크림 	3,000
# 2     바나나       	4,000
# 3     딸기        	5,000
# 4     벌집꿀       	7,000
# 5     그레놀라      	7,000
# 6     초코쉘       	7,000
# ------------------------------
# ****************************************
#
# ========================================
# 현재 장바구니
# 1. 요거트 아이스크림 x 1 = 3,000원
# ----------------------------------------
# Total = 3,000원
# 메뉴를 확정하려면 1
# 메뉴를 삭제하려면 2
# 메뉴를 추가하려면 3
# 메뉴를 취소하려면 4
# 번호를 입력해주세요 :  99
# 관리자 모드에 접속합니다.
#
# [관리자 기능]
# 1. 메뉴 추가
# 2. 메뉴 삭제
# 3. 관리자 모드 종료
# 번호를 입력해주세요:  1
# 추가할 메뉴 이름을 입력하세요:  콘프러스트
# 가격을 입력하세요:  4000
# '콘프러스트'(가격: 4,000원)이 메뉴에 추가되었습니다.
# 관리자 중지입니다.
#
# ========================================
# 현재 장바구니
# 1. 요거트 아이스크림 x 1 = 3,000원
# ----------------------------------------
# Total = 3,000원
# 메뉴를 확정하려면 1
# 메뉴를 삭제하려면 2
# 메뉴를 추가하려면 3
# 메뉴를 취소하려면 4
# 번호를 입력해주세요 :  3
# 메뉴 목록:
# 1. 요거트 아이스크림 : 3,000원
# 2. 바나나 : 4,000원
# 3. 딸기 : 5,000원
# 4. 벌집꿀 : 7,000원
# 5. 그레놀라 : 7,000원
# 6. 초코쉘 : 7,000원
# 7. 콘프러스트 : 4,000원
# 추가할 토핑 번호를 골라주세요 : 7
# 수량을 선택해주세요 :  1
# ========================================
# 현재 장바구니
# 1. 요거트 아이스크림 x 1 = 3,000원
# 2. 콘프러스트 x 1 = 4,000원
# ----------------------------------------
# Total = 7,000원
#
# [관리자 기능]
# 1. 메뉴 추가
# 2. 메뉴 삭제
# 3. 관리자 모드 종료
# 번호를 입력해주세요:  1
# 추가할 메뉴 이름을 입력하세요:  7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 141
#     138 if admin_choice == 1:
#     139     # 메뉴 추가 기능
#     140     new_name = input("추가할 메뉴 이름을 입력하세요: ")
# --> 141     new_price = int(input("가격을 입력하세요: "))
#     142     menu_list.append({'name': new_name, 'price': new_price})
#     143     print(f"'{new_name}'(가격: {new_price:,}원)이 메뉴에 추가되었습니다.")
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\miniconda3\envs\hipython\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
