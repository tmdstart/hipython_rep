# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

test_df = pd.read_csv('./test.csv')
test_df
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-20 00:00:00       1        0           1        1  10.66
# 1     2011-01-20 01:00:00       1        0           1        1  10.66
# 2     2011-01-20 02:00:00       1        0           1        1  10.66
# 3     2011-01-20 03:00:00       1        0           1        1  10.66
# 4     2011-01-20 04:00:00       1        0           1        1  10.66
# ...                   ...     ...      ...         ...      ...    ...
# 6488  2012-12-31 19:00:00       1        0           1        2  10.66
# 6489  2012-12-31 20:00:00       1        0           1        2  10.66
# 6490  2012-12-31 21:00:00       1        0           1        1  10.66
# 6491  2012-12-31 22:00:00       1        0           1        1  10.66
# 6492  2012-12-31 23:00:00       1        0           1        1  10.66
#
#        atemp  humidity  windspeed
# 0     11.365        56    26.0027
# 1     13.635        56     0.0000
# ...

# %%
sub_df = pd.read_csv('./sampleSubmission.csv')
sub_df
# Out:
#                  datetime  count
# 0     2011-01-20 00:00:00      0
# 1     2011-01-20 01:00:00      0
# 2     2011-01-20 02:00:00      0
# 3     2011-01-20 03:00:00      0
# 4     2011-01-20 04:00:00      0
# ...                   ...    ...
# 6488  2012-12-31 19:00:00      0
# 6489  2012-12-31 20:00:00      0
# 6490  2012-12-31 21:00:00      0
# 6491  2012-12-31 22:00:00      0
# 6492  2012-12-31 23:00:00      0
#
# [6493 rows x 2 columns]

# %%
train_df = pd.read_csv('./train.csv')
train_df['datetime'] = pd.to_datetime(train_df['datetime'])

# 2. 'datetime' 컬럼에서 숫자 특성 추출
train_df['year'] = train_df['datetime'].dt.year
train_df['month'] = train_df['datetime'].dt.month
train_df['day'] = train_df['datetime'].dt.day
train_df['hour'] = train_df['datetime'].dt.hour
train_df['dayofweek'] = train_df['datetime'].dt.dayofweek # 월요일=0, 일요일=6

# %%
train_df
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  year  month  \
# ...

# %%
# 중복 데이터 확인 및 제거
display(train_df[train_df.duplicated(keep=False)])
train_df = train_df.drop_duplicates()
# Out:
# Empty DataFrame
# Columns: [datetime, season, holiday, workingday, weather, temp, atemp, humidity, windspeed, casual, registered, count, year, month, day, hour, dayofweek]
# Index: []

# %%
train_df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    dayofweek
# 0          5
# 1          5
# 2          5
# 3          5
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = train_df.drop('count', axis =1).values
y = train_df['count'].values
train_df.shape
# Out:
# (10886, 17)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=156)
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
y_pred[:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=156)
#       2 lr = LinearRegression()
# ----> 3 lr.fit(X_train, y_train)
#       4 y_pred = lr.predict(X_test)
#       5 y_pred[:3]
#
# File c:\Users\Admin\miniconda3\envs\hi_ml_env\lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# 실제 데이터를 불러오는 부분 (예: train_df = pd.read_csv('your_train_data.csv'))
# 여기에 실제 데이터를 불러오는 코드를 넣어주세요.
# 예를 들어, 데이터가 'bike_sharing_train.csv' 파일에 있다고 가정합니다.
# train_df = pd.read_csv('bike_sharing_train.csv').

train_df = pd.DataFrame(data)


# 1. 'datetime' 컬럼을 datetime 객체로 변환
train_df['datetime'] = pd.to_datetime(train_df['datetime'])

train_df['year'] = train_df['datetime'].dt.year
train_df['month'] = train_df['datetime'].dt.month
train_df['day'] = train_df['datetime'].dt.day
train_df['hour'] = train_df['datetime'].dt.hour
train_df['dayofweek'] = train_df['datetime'].dt.dayofweek # 월요일=0, 일요일=6

X = train_df.drop(['datetime', 'casual', 'registered', 'count'], axis=1) 
y = train_df['count'] 

# --- 데이터 타입 및 결측치 최종 확인 ---
#print("X DataFrame info before training:")
#X.info() # 모든 컬럼의 Dtype이 숫자형(int64, float64 등)인지 확인

#print("\nMissing values in X:")
#print(X.isnull().sum()) 

#print("\nMissing values in y:")
#print(y.isnull().sum()) 


# 학습/테스트 데이터 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=156)

# 선형 회귀 모델 훈련
lr = LinearRegression()
lr.fit(X_train, y_train)

# 예측
y_pred = lr.predict(X_test)
print(y_pred[:3])
# Out:
# [206.69609203   5.         161.9140654 ]

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# np.float64(0.9089912887265154)
