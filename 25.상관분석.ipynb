# %%
from scipy.stats import binom, norm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('./data/datalab6.csv', sep=',', encoding='utf-8')
df.head()

corr_df = df[['스트레스', '퇴사']]
corr_df.corr()

import matplotlib.pyplot as plt
plt.scatter(corr_df['스트레스'], corr_df['퇴사'] )
plt.show()

# %%
import pandas as pd
from scipy.stats import pearsonr

# 예시 데이터
data = {
    'height': [160, 165, 170, 175, 180],
    'weight': [50, 55, 65, 70, 80]
}
df = pd.DataFrame(data)

# 피어슨 상관계수 계산
corr, p_value = pearsonr(df['height'], df['weight'])

print(f"피어슨 상관계수: {corr:.2f}")
print(f"p-값: {p_value:.4f}")
# Out:
# 피어슨 상관계수: 0.99
# p-값: 0.0006

# %%
import pandas as pd
from scipy.stats import spearmanr

# 데이터프레임 구성
data = {
    'student': ['A', 'B', 'C', 'D', 'E'],
    'academic_rank': [1, 2, 3, 4, 5],
    'sports_rank': [4, 2, 1, 3, 5]
}
df = pd.DataFrame(data)

# 스피어만 상관계수 계산 
rho, pval = spearmanr(df['academic_rank'], df['sports_rank'])

print(f"스피어만 상관계수: {rho:.3f}")
print(f"p-value: {pval:.4f}")
# Out:
# 스피어만 상관계수: 0.300
# p-value: 0.6238

# %%
def my_function(x):
  return 5 * x + 7

val = int(input('숫자를 입력하세요 : '))
ret = my_function(val)
print(ret)
# Out:
# 52
